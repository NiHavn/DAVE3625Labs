# %%
#imports
from faker import Faker
import pandas as pd
from faker.providers.credit_card import Provider as CreditCardProvider

# %%
#Sets faker to norwegian language
faker = Faker(['no_NO'])
#Makes header for the table
df = pd.DataFrame(columns=['Navn', 'Adresse', 'PrsonNr', 'KredittKort', 'ipv4'])

#Prints out 100 people in the table
for x in range(0, 100):
    row = [faker.name(), faker.address(), faker.ssn(), faker.credit_card_number(), faker.ipv4()]
    df.loc[len(df)] = row

df
# Out:
#                      Navn                               Adresse      PrsonNr  \
# 0   Magnus-Thor Jørgensen       Eideskogen 58B, 6556 Ingridsund  12113543750
# 1            Eli Amundsen         Danielsenekra 4A, 9917 Nilsen  13069908912
# 2               Espen Aas      Mathisenstien 62F, 2079 Eliassen  15073737246
# 3         Camilla Karlsen           Evensenhavna 2A, 9720 Olsen  09105000879
# 4               Hege Moen        Karlsenhøgda 4, 3920 Lailahamn  19015133514
# ..                    ...                                   ...          ...
# 95           Jonas Tangen        Bøebakken 5C, 9123 Torbjørndal  08079127435
# 96           Arild Nilsen              Hauggrenda 3, 6031 Bakke  11040472004
# 97  Monica-Mari Mikkelsen        Johansentunet 15, 9830 Iversen  25126630029
# 98     Grethe-Bjørg Lunde  Christensenmarka 38D, 8093 Sveinhavn  24105534910
# 99      Sigurd-Pål Brekke    Tangenstykket 7F, 5298 Elisestrand  16108231630
#
#             KredittKort             ipv4
# ...
