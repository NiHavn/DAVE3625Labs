# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re

url = 'https://raw.githubusercontent.com/atikagondal/Lab-2023-DAVE3625/main/Lab%202/data/Titanic.csv'
df = pd.read_csv(url)

df
# Out:
#       PassengerId  Pclass                                               Name  \
# 0               1       3                            Braund, Mr. Owen Harris
# 1               2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2               3       3                             Heikkinen, Miss. Laina
# 3               4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4               5       3                           Allen, Mr. William Henry
# ...           ...     ...                                                ...
# 1304         1305       3                                 Spector, Mr. Woolf
# 1305         1306       1                       Oliva y Ocana, Dona. Fermina
# 1306         1307       3                       Saether, Mr. Simon Sivertsen
# 1307         1308       3                                Ware, Mr. Frederick
# 1308         1309       3                           Peter, Master. Michael J
#
#          Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 0       male  22.0      1      0           A/5 21171    7.2500   NaN        S
# 1     female  38.0      1      0            PC 17599   71.2833   C85        C
# 2     female  26.0      0      0    STON/O2. 3101282    7.9250   NaN        S
# 3     female  35.0      1      0              113803   53.1000  C123        S
# 4       male  35.0      0      0              373450    8.0500   NaN        S
# ...      ...   ...    ...    ...                 ...       ...   ...      ...
# 1304    male   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 1305  female  39.0      0      0            PC 17758  108.9000  C105        C
# 1306    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 1307    male   NaN      0      0              359309    8.0500   NaN        S
# 1308    male   NaN      1      1                2668   22.3583   NaN        C
#
# [1309 rows x 11 columns]

# %%
df.isna().sum()
# Out:
# PassengerId       0
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# dtype: int64

# %%
#Fjerner NaN values i Age, Fare og Embarked kolonnene
df["Age"] = df["Age"].fillna(df["Age"].median())
df["Fare"] = df["Fare"].fillna(df["Fare"].median)
df["Embarked"] = "S"

df
# Out:
#       PassengerId  Pclass                                               Name  \
# 0               1       3                            Braund, Mr. Owen Harris
# 1               2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2               3       3                             Heikkinen, Miss. Laina
# 3               4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4               5       3                           Allen, Mr. William Henry
# ...           ...     ...                                                ...
# 1304         1305       3                                 Spector, Mr. Woolf
# 1305         1306       1                       Oliva y Ocana, Dona. Fermina
# 1306         1307       3                       Saether, Mr. Simon Sivertsen
# 1307         1308       3                                Ware, Mr. Frederick
# 1308         1309       3                           Peter, Master. Michael J
#
#          Sex   Age  SibSp  Parch              Ticket     Fare Cabin Embarked
# 0       male  22.0      1      0           A/5 21171     7.25   NaN        S
# 1     female  38.0      1      0            PC 17599  71.2833   C85        S
# 2     female  26.0      0      0    STON/O2. 3101282    7.925   NaN        S
# 3     female  35.0      1      0              113803     53.1  C123        S
# 4       male  35.0      0      0              373450     8.05   NaN        S
# ...      ...   ...    ...    ...                 ...      ...   ...      ...
# 1304    male  28.0      0      0           A.5. 3236     8.05   NaN        S
# 1305  female  39.0      0      0            PC 17758    108.9  C105        S
# 1306    male  38.5      0      0  SOTON/O.Q. 3101262     7.25   NaN        S
# 1307    male  28.0      0      0              359309     8.05   NaN        S
# 1308    male  28.0      1      1                2668  22.3583   NaN        S
#
# [1309 rows x 11 columns]

# %%
#Lager boolske verdier for kolonnen Cabin
df["HasCabin"] = ~df.Cabin.isnull()

df.head()
# Out:
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3       3                             Heikkinen, Miss. Laina
# 3            4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171     7.25   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        S
# 2  female  26.0      0      0  STON/O2. 3101282    7.925   NaN        S
# 3  female  35.0      1      0            113803     53.1  C123        S
# 4    male  35.0      0      0            373450     8.05   NaN        S
#
#    HasCabin
# 0     False
# 1      True
# 2     False
# 3      True
# 4     False

# %%
lambda x: re.search('([A-Z][a-z]+)\.', x).group(1)

df["Title"] = df.Name.apply(lambda x: re.search('([A-Z][a-z]+)\.', x).group(1))

df.head()
# Out:
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3       3                             Heikkinen, Miss. Laina
# 3            4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171     7.25   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        S
# 2  female  26.0      0      0  STON/O2. 3101282    7.925   NaN        S
# 3  female  35.0      1      0            113803     53.1  C123        S
# 4    male  35.0      0      0            373450     8.05   NaN        S
#
#    HasCabin Title
# 0     False    Mr
# 1      True   Mrs
# 2     False  Miss
# 3      True   Mrs
# 4     False    Mr

# %%
df["Title"].value_counts()
# Out:
# Title
# Mr          757
# Miss        260
# Mrs         197
# Master       61
# Rev           8
# Dr            8
# Col           4
# Mlle          2
# Major         2
# Ms            2
# Lady          1
# Sir           1
# Mme           1
# Don           1
# Capt          1
# Countess      1
# Jonkheer      1
# Dona          1
# Name: count, dtype: int64

# %%
df["Title"] = df["Title"].replace({'Mlle''Ms':'Miss', 'Mme':'Mr'})
df["Title"] = df["Title"].replace(["Rev","Dr","Col", "Major", "Lady", "Sir", "Don",
                                   "Capt", "Countess", "Jonkheer", "Dona"], "Unique")

df["Title"].value_counts()
# Out:
# Title
# Mr        758
# Miss      260
# Mrs       197
# Master     61
# Unique     29
# Ms          2
# Mlle        2
# Name: count, dtype: int64

# %%
sns.countplot(x='Title', data=df);
plt.xticks(rotation=45);

# %%
df['CatAge'] = pd.qcut(df["Age"], q=4, labels=False)
df['CatFare'] = pd.qcut(df["Fare"], q=4, labels=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\Niklas Havnaas\OneDrive\Skrivebord\Skole\DAVE3625\Dave3625Labs\Lab3\DAVE3625Labs\Lab2\oppg3.ipynb Cell 9 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/Niklas%20Havnaas/OneDrive/Skrivebord/Skole/DAVE3625/Dave3625Labs/Lab3/DAVE3625Labs/Lab2/oppg3.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> df['CatAge'] = pd.qcut(df["Age"], q=4, labels=False)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Niklas%20Havnaas/OneDrive/Skrivebord/Skole/DAVE3625/Dave3625Labs/Lab3/DAVE3625Labs/Lab2/oppg3.ipynb#X11sZmlsZQ%3D%3D?line=1'>2</a> df['CatFare'] = pd.qcut(df["Fare"], q=4, labels=False)
#
# File c:\Users\Niklas Havnaas\miniconda3\envs\dave3625\lib\site-packages\pandas\core\reshape\tile.py:376, in qcut(x, q, labels, retbins, precision, duplicates)
#     373 quantiles = np.linspace(0, 1, q + 1) if is_integer(q) else q
#     375 x_np = np.asarray(x)
# --> 376 x_np = x_np[~np.isnan(x_np)]
#     377 bins = np.quantile(x_np, quantiles)
#     379 fac, bins = _bins_to_cuts(
#     380     x,
#     381     bins,
#    (...)
#     386     duplicates=duplicates,
#     387 )
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
